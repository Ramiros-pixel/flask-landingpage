# %% [markdown]
# A. Soal Dasar (Pengenalan DataFrame)

# %% [markdown]
# 1.	Import library pandas, baca file data_dm_jabar.csv ke dalam DataFrame bernama df, lalu tampilkan 5 baris pertama.

# %%
import pandas as pd

df= pd.read_csv('static/download/data1.csv')
lima_baris = df.head(5)
print(lima_baris.to_string())
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR                57769  ORANG   2019
# 1   2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI               148447  ORANG   2019
# 2   3             32    JAWA BARAT                 3203   KABUPATEN CIANJUR                12100  ORANG   2019
# 3   4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG                45412  ORANG   2019
# 4   5             32    JAWA BARAT                 3205     KABUPATEN GARUT                    0  ORANG   2019

# %% [markdown]
# 2.	Tampilkan 5 baris terakhir dari df.

# %%
lima_baris_akhir = df.tail(5)
print(lima_baris_akhir.to_string())
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 157  158             32    JAWA BARAT                 3275         KOTA BEKASI                46481  ORANG   2024
# 158  159             32    JAWA BARAT                 3276          KOTA DEPOK                44061  ORANG   2024
# 159  160             32    JAWA BARAT                 3277         KOTA CIMAHI                10021  ORANG   2024
# 160  161             32    JAWA BARAT                 3278    KOTA TASIKMALAYA                11782  ORANG   2024
# 161  162             32    JAWA BARAT                 3279         KOTA BANJAR                 2415  ORANG   2024

# %% [markdown]
# 3.	Tampilkan informasi struktur DataFrame menggunakan df.info().

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   162 non-null    int64
#  1   kode_provinsi        162 non-null    int64
#  2   nama_provinsi        162 non-null    object
#  3   kode_kabupaten_kota  162 non-null    int64
#  4   nama_kabupaten_kota  162 non-null    object
#  5   jumlah_penderita_dm  162 non-null    int64
#  6   satuan               162 non-null    object
#  7   tahun                162 non-null    int64
# dtypes: int64(5), object(3)
# memory usage: 10.3+ KB

# %% [markdown]
# 4.	Tampilkan statistik deskriptif untuk kolom numerik (misalnya jumlah_penderita_dm dan tahun) menggunakan df.describe().

# %%
df[['jumlah_penderita_dm', 'tahun']].describe()
# Out:
#        jumlah_penderita_dm        tahun
# count           162.000000   162.000000
# mean          29699.388889  2021.500000
# std           31787.221502     1.713121
# min               0.000000  2019.000000
# 25%           12306.000000  2020.000000
# 50%           19279.000000  2021.500000
# 75%           39988.750000  2023.000000
# max          242169.000000  2024.000000

# %% [markdown]
# 5.	Tampilkan daftar nilai unik dari kolom tahun.

# %%
df_unik_tahun = df.groupby('tahun').nunique().reset_index()
df_unik_tahun
# Out:
#    tahun  id  kode_provinsi  nama_provinsi  kode_kabupaten_kota  \
# 0   2019  27              1              1                   27
# 1   2020  27              1              1                   27
# 2   2021  27              1              1                   27
# 3   2022  27              1              1                   27
# 4   2023  27              1              1                   27
# 5   2024  27              1              1                   27
#
#    nama_kabupaten_kota  jumlah_penderita_dm  satuan
# 0                   27                   21       1
# 1                   27                   27       1
# 2                   27                   27       1
# 3                   27                   27       1
# 4                   27                   27       1
# 5                   27                   27       1

# %% [markdown]
# 6.	Tampilkan daftar nilai unik dari kolom nama_kabupaten_kota dan hitung berapa banyak kabupaten/kota yang tercatat.

# %%
daftar_kabkot = df['nama_kabupaten_kota'].unique()
print(daftar_kabkot)
jumlah_kabkot = df['nama_kabupaten_kota'].nunique()
print("Jumlah kabupaten/kota yang tercatat:", jumlah_kabkot)
# Out:
# ['KABUPATEN BOGOR' 'KABUPATEN SUKABUMI' 'KABUPATEN CIANJUR'
#  'KABUPATEN BANDUNG' 'KABUPATEN GARUT' 'KABUPATEN TASIKMALAYA'
#  'KABUPATEN CIAMIS' 'KABUPATEN KUNINGAN' 'KABUPATEN CIREBON'
#  'KABUPATEN MAJALENGKA' 'KABUPATEN SUMEDANG' 'KABUPATEN INDRAMAYU'
#  'KABUPATEN SUBANG' 'KABUPATEN PURWAKARTA' 'KABUPATEN KARAWANG'
#  'KABUPATEN BEKASI' 'KABUPATEN BANDUNG BARAT' 'KABUPATEN PANGANDARAN'
#  'KOTA BOGOR' 'KOTA SUKABUMI' 'KOTA BANDUNG' 'KOTA CIREBON' 'KOTA BEKASI'
#  'KOTA DEPOK' 'KOTA CIMAHI' 'KOTA TASIKMALAYA' 'KOTA BANJAR']
# Jumlah kabupaten/kota yang tercatat: 27

# %% [markdown]
# 7.	Tampilkan hanya kolom: nama_kabupaten_kota, jumlah_penderita_dm, dan tahun.

# %%
df[["nama_kabupaten_kota","jumlah_penderita_dm","tahun"]]
# Out:
#     nama_kabupaten_kota  jumlah_penderita_dm  tahun
# 0       KABUPATEN BOGOR                57769   2019
# 1    KABUPATEN SUKABUMI               148447   2019
# 2     KABUPATEN CIANJUR                12100   2019
# 3     KABUPATEN BANDUNG                45412   2019
# 4       KABUPATEN GARUT                    0   2019
# ..                  ...                  ...    ...
# 157         KOTA BEKASI                46481   2024
# 158          KOTA DEPOK                44061   2024
# 159         KOTA CIMAHI                10021   2024
# 160    KOTA TASIKMALAYA                11782   2024
# 161         KOTA BANJAR                 2415   2024
#
# [162 rows x 3 columns]

# %% [markdown]
# B. Soal Pengolahan Data

# %% [markdown]
# 8.	Tampilkan semua baris data untuk tahun 2019 saja.

# %%
data_2019 = df[df["tahun"]==2019]
data_2019
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0    1             32    JAWA BARAT                 3201
# 1    2             32    JAWA BARAT                 3202
# 2    3             32    JAWA BARAT                 3203
# 3    4             32    JAWA BARAT                 3204
# 4    5             32    JAWA BARAT                 3205
# 5    6             32    JAWA BARAT                 3206
# 6    7             32    JAWA BARAT                 3207
# 7    8             32    JAWA BARAT                 3208
# 8    9             32    JAWA BARAT                 3209
# 9   10             32    JAWA BARAT                 3210
# 10  11             32    JAWA BARAT                 3211
# 11  12             32    JAWA BARAT                 3212
# 12  13             32    JAWA BARAT                 3213
# 13  14             32    JAWA BARAT                 3214
# 14  15             32    JAWA BARAT                 3215
# ...

# %% [markdown]
# 9.	Tampilkan semua kabupaten/kota yang memiliki jumlah_penderita_dm lebih dari 100.000 orang (tahun berapa pun).

# %%
penderita_tinggi = df[df['jumlah_penderita_dm']>100000]
penderita_tinggi
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 1    2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 14  15             32    JAWA BARAT                 3215  KABUPATEN KARAWANG
# 41  42             32    JAWA BARAT                 3215  KABUPATEN KARAWANG
# 42  43             32    JAWA BARAT                 3216    KABUPATEN BEKASI
# 68  69             32    JAWA BARAT                 3215  KABUPATEN KARAWANG
#
#     jumlah_penderita_dm satuan  tahun
# 1                148447  ORANG   2019
# 14               149537  ORANG   2019
# 41               139392  ORANG   2020
# 42               242169  ORANG   2020
# 68               153547  ORANG   2021

# %% [markdown]
# 10.	Urutkan DataFrame berdasarkan jumlah_penderita_dm dari terbesar ke terkecil.

# %%
df_sorted = df.sort_values(by='jumlah_penderita_dm', ascending=False)
df_sorted[['nama_kabupaten_kota', 'jumlah_penderita_dm', 'tahun']]
# Out:
#         nama_kabupaten_kota  jumlah_penderita_dm  tahun
# 42         KABUPATEN BEKASI               242169   2020
# 68       KABUPATEN KARAWANG               153547   2021
# 14       KABUPATEN KARAWANG               149537   2019
# 1        KABUPATEN SUKABUMI               148447   2019
# 41       KABUPATEN KARAWANG               139392   2020
# ..                      ...                  ...    ...
# 19            KOTA SUKABUMI                    0   2019
# 4           KABUPATEN GARUT                    0   2019
# 10       KABUPATEN SUMEDANG                    0   2019
# 16  KABUPATEN BANDUNG BARAT                    0   2019
# 17    KABUPATEN PANGANDARAN                    0   2019
#
# [162 rows x 3 columns]

# %% [markdown]
# 11.	Urutkan DataFrame berdasarkan tahun terlebih dahulu, lalu jumlah_penderita_dm dari yang terbesar.

# %%
df_sorted = df.sort_values(
    by=['tahun', 'jumlah_penderita_dm'],
    ascending=[True, False]
)
df_sorted
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 14    15             32    JAWA BARAT                 3215
# 1      2             32    JAWA BARAT                 3202
# 15    16             32    JAWA BARAT                 3216
# 6      7             32    JAWA BARAT                 3207
# 0      1             32    JAWA BARAT                 3201
# ..   ...            ...           ...                  ...
# 159  160             32    JAWA BARAT                 3277
# 156  157             32    JAWA BARAT                 3274
# 152  153             32    JAWA BARAT                 3218
# 154  155             32    JAWA BARAT                 3272
# 161  162             32    JAWA BARAT                 3279
#
#        nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 14      KABUPATEN KARAWANG               149537  ORANG   2019
# 1       KABUPATEN SUKABUMI               148447  ORANG   2019
# 15        KABUPATEN BEKASI                89055  ORANG   2019
# ...

# %% [markdown]
# 12.	Tampilkan 10 kabupaten/kota dengan jumlah penderita DM tertinggi pada tahun 2019.

# %%
penderita_tertinggi_2019 = data_2019.sort_values(by='jumlah_penderita_dm', ascending=False)
penderita_tertinggi_2019.head(10)
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 14  15             32    JAWA BARAT                 3215  KABUPATEN KARAWANG
# 1    2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 15  16             32    JAWA BARAT                 3216    KABUPATEN BEKASI
# 6    7             32    JAWA BARAT                 3207    KABUPATEN CIAMIS
# 0    1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 23  24             32    JAWA BARAT                 3276          KOTA DEPOK
# 20  21             32    JAWA BARAT                 3273        KOTA BANDUNG
# 3    4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 22  23             32    JAWA BARAT                 3275         KOTA BEKASI
# 7    8             32    JAWA BARAT                 3208  KABUPATEN KUNINGAN
#
#     jumlah_penderita_dm satuan  tahun
# 14               149537  ORANG   2019
# 1                148447  ORANG   2019
# ...

# %% [markdown]
# 13.	Tampilkan semua baris data untuk satu kabupaten pilihanmu (misal: KABUPATEN BOGOR) di semua tahun yang tersedia.

# %%
data_kota_bandung = df[df['nama_kabupaten_kota']=='KABUPATEN BANDUNG']
data_kota_bandung
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 3      4             32    JAWA BARAT                 3204
# 30    31             32    JAWA BARAT                 3204
# 57    58             32    JAWA BARAT                 3204
# 84    85             32    JAWA BARAT                 3204
# 111  112             32    JAWA BARAT                 3204
# 138  139             32    JAWA BARAT                 3204
#
#     nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 3     KABUPATEN BANDUNG                45412  ORANG   2019
# 30    KABUPATEN BANDUNG                32847  ORANG   2020
# 57    KABUPATEN BANDUNG                82787  ORANG   2021
# 84    KABUPATEN BANDUNG                45465  ORANG   2022
# 111   KABUPATEN BANDUNG                59205  ORANG   2023
# 138   KABUPATEN BANDUNG                44200  ORANG   2024

# %% [markdown]
# C. Soal Agregasi & Transformasi

# %% [markdown]
# 14.	Kelompokkan data berdasarkan tahun dan hitung total jumlah_penderita_dm per tahun di Jawa Barat.

# %%
jumlah_penderita_pertahun = df.groupby('tahun')['jumlah_penderita_dm'].sum().reset_index()
jumlah_penderita_pertahun
# Out:
#    tahun  jumlah_penderita_dm
# 0   2019               848455
# 1   2020              1078857
# 2   2021               925675
# 3   2022               644704
# 4   2023               645390
# 5   2024               668220

# %% [markdown]
# 15.	Kelompokkan data berdasarkan nama_kabupaten_kota dan hitung rata-rata jumlah_penderita_dm tiap kabupaten/kota (jika terdapat lebih dari satu tahun).

# %%
df_kabupaten_kota = df.groupby('nama_kabupaten_kota')['jumlah_penderita_dm'].mean().reset_index().rename(columns={'jumlah_penderita_dm': 'mean_penderita_dm'})
df_kabupaten_kota
# Out:
#         nama_kabupaten_kota  mean_penderita_dm
# 0         KABUPATEN BANDUNG       51652.666667
# 1   KABUPATEN BANDUNG BARAT       14246.333333
# 2          KABUPATEN BEKASI       81174.333333
# 3           KABUPATEN BOGOR       64286.500000
# 4          KABUPATEN CIAMIS       38304.000000
# 5         KABUPATEN CIANJUR       14363.166667
# 6         KABUPATEN CIREBON       20553.333333
# 7           KABUPATEN GARUT       20789.833333
# 8       KABUPATEN INDRAMAYU       33056.666667
# 9        KABUPATEN KARAWANG       92411.000000
# 10       KABUPATEN KUNINGAN       21259.333333
# 11     KABUPATEN MAJALENGKA       13028.333333
# 12    KABUPATEN PANGANDARAN        7100.500000
# 13     KABUPATEN PURWAKARTA       12953.500000
# 14         KABUPATEN SUBANG       24120.166667
# 15       KABUPATEN SUKABUMI       45277.500000
# 16       KABUPATEN SUMEDANG       34894.000000
# 17    KABUPATEN TASIKMALAYA       18176.333333
# 18             KOTA BANDUNG       43480.166667
# ...

# %% [markdown]
# 16.	Tentukan kabupaten/kota dengan total jumlah_penderita_dm tertinggi dan terendah di seluruh tahun.

# %%
df_kabkot = df.groupby('nama_kabupaten_kota')['jumlah_penderita_dm'].sum().reset_index()
kabkot_tertinggi = df_kabkot.loc[df_kabkot['jumlah_penderita_dm'].idxmax()]
kabkot_terendah = df_kabkot.loc[df_kabkot['jumlah_penderita_dm'].idxmin()]

print(f"Daerah dengan total penderita DM tertinggi adalah {kabkot_tertinggi['nama_kabupaten_kota']} sebanyak {kabkot_tertinggi['jumlah_penderita_dm']} penderita.")

print(f"Daerah dengan total penderita DM terendah adalah {kabkot_terendah['nama_kabupaten_kota']} sebanyak {kabkot_terendah['jumlah_penderita_dm']} penderita.")
# Out:
# Daerah dengan total penderita DM tertinggi adalah KABUPATEN KARAWANG sebanyak 554466 penderita.
# Daerah dengan total penderita DM terendah adalah KOTA BANJAR sebanyak 21664 penderita.

# %% [markdown]
# Validasi no.16

# %%
df_kabkot.sort_values(by='jumlah_penderita_dm', ascending=False)
# Out:
#         nama_kabupaten_kota  jumlah_penderita_dm
# 9        KABUPATEN KARAWANG               554466
# 2          KABUPATEN BEKASI               487046
# 3           KABUPATEN BOGOR               385719
# 0         KABUPATEN BANDUNG               309916
# 24               KOTA DEPOK               276630
# 20              KOTA BEKASI               274614
# 15       KABUPATEN SUKABUMI               271665
# 18             KOTA BANDUNG               260881
# 4          KABUPATEN CIAMIS               229824
# 16       KABUPATEN SUMEDANG               209364
# 8       KABUPATEN INDRAMAYU               198340
# 14         KABUPATEN SUBANG               144721
# 10       KABUPATEN KUNINGAN               127556
# 7           KABUPATEN GARUT               124739
# 6         KABUPATEN CIREBON               123320
# 17    KABUPATEN TASIKMALAYA               109058
# 21               KOTA BOGOR               103936
# 5         KABUPATEN CIANJUR                86179
# ...

# %% [markdown]
# 17.	Buat kolom baru bernama kategori_dm dengan aturan berbasis jumlah_penderita_dm: < 50.000 → "Rendah", 50.000–99.999 → "Sedang", >= 100.000 → "Tinggi"

# %%
df['kategori_dm'] = pd.cut(
    df['jumlah_penderita_dm'],
    bins=[-1, 49999, 99999, float('inf')],
    labels=['Rendah', 'Sedang', 'Tinggi']
)
df
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 157  158             32    JAWA BARAT                 3275
# 158  159             32    JAWA BARAT                 3276
# 159  160             32    JAWA BARAT                 3277
# 160  161             32    JAWA BARAT                 3278
# 161  162             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun kategori_dm
# 0       KABUPATEN BOGOR                57769  ORANG   2019      Sedang
# 1    KABUPATEN SUKABUMI               148447  ORANG   2019      Tinggi
# ...

# %% [markdown]
# 18.	Untuk setiap tahun, hitung persentase jumlah penderita DM per kabupaten/kota terhadap total jumlah penderita DM di tahun tersebut, lalu simpan dalam kolom baru bernama persentase_tahun.

# %%
df['persentase_tahun'] = ( df['jumlah_penderita_dm'] / df.groupby('tahun')['jumlah_penderita_dm'].transform('sum')) * 100
df['persentase_tahun'] = df['persentase_tahun'].round(2)
df
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 157  158             32    JAWA BARAT                 3275
# 158  159             32    JAWA BARAT                 3276
# 159  160             32    JAWA BARAT                 3277
# 160  161             32    JAWA BARAT                 3278
# 161  162             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun kategori_dm  \
# 0       KABUPATEN BOGOR                57769  ORANG   2019      Sedang
# 1    KABUPATEN SUKABUMI               148447  ORANG   2019      Tinggi
# ...

# %% [markdown]
# 19.	Buat tabel ringkas (misalnya menggunakan groupby) yang menunjukkan:
# tahun, total_jumlah_penderita_dm, dan jumlah_kabupaten_kota yang datanya tercatat di tahun tersebut.

# %%
tabel_ringkas = (
    df.groupby('tahun')
      .agg(
          total_jumlah_penderita_dm=('jumlah_penderita_dm', 'sum'),
          jumlah_kabupaten_kota=('nama_kabupaten_kota', 'nunique')
      )
      .reset_index()
)

tabel_ringkas
# Out:
#    tahun  total_jumlah_penderita_dm  jumlah_kabupaten_kota
# 0   2019                     848455                     27
# 1   2020                    1078857                     27
# 2   2021                     925675                     27
# 3   2022                     644704                     27
# 4   2023                     645390                     27
# 5   2024                     668220                     27

# %% [markdown]
# D. Soal Analisis & Visualisasi (Matplotlib)

# %% [markdown]
# 20.	Buat grafik bar yang menampilkan jumlah_penderita_dm untuk setiap kabupaten/kota pada tahun 2019. Sumbu-x: nama_kabupaten_kota. Sumbu-y: jumlah_penderita_dm. Beri judul dan label sumbu yang jelas.

# %%
import matplotlib.pyplot as plt

df_2019 = df[df['tahun'] == 2019]

plt.figure()
plt.bar(df_2019['nama_kabupaten_kota'], df_2019['jumlah_penderita_dm'])
plt.xticks(rotation=90)
plt.xlabel('Nama Kabupaten/Kota')
plt.ylabel('Jumlah Penderita DM')
plt.title('Jumlah Penderita Diabetes Mellitus per Kabupaten/Kota Tahun 2019')
plt.tight_layout()
plt.show()

# %% [markdown]
# 21.	Buat grafik garis (line chart) yang menampilkan total jumlah penderita DM Jawa Barat per tahun. Sumbu-x: tahun. Sumbu-y: total jumlah_penderita_dm. Tambahkan titik data (marker) di setiap tahun.

# %%
total_per_tahun = (
    df.groupby('tahun')['jumlah_penderita_dm']
      .sum()
      .reset_index()
)

plt.figure()
plt.plot(
    total_per_tahun['tahun'],
    total_per_tahun['jumlah_penderita_dm'],
    marker='o'
)

plt.xlabel('Tahun')
plt.ylabel('Total Jumlah Penderita DM')
plt.title('Total Jumlah Penderita Diabetes Mellitus di Jawa Barat per Tahun')
plt.tight_layout()
plt.show()

# %% [markdown]
# 22.	Buat grafik bar horizontal untuk menampilkan 10 kabupaten/kota dengan jumlah_penderita_dm tertinggi pada tahun 2019. Urutkan dari jumlah tertinggi ke terendah.

# %%
df_2019 = df[df['tahun'] == 2019]

top10_2019 = (
    df_2019.sort_values(by='jumlah_penderita_dm', ascending=False)
           .head(10)
)

plt.figure()
plt.barh(
    top10_2019['nama_kabupaten_kota'],
    top10_2019['jumlah_penderita_dm']
)
plt.xlabel('Jumlah Penderita DM')
plt.ylabel('Nama Kabupaten/Kota')
plt.title('10 Kabupaten/Kota dengan Jumlah Penderita Diabetes Mellitus Tertinggi pada Tahun 2019')
plt.gca().invert_yaxis()  # tertinggi di atas
plt.tight_layout()
plt.show()

# %% [markdown]
# 23.	Buat pie chart yang menunjukkan proporsi jumlah_penderita_dm berdasarkan kategori_dm ("Rendah", "Sedang", "Tinggi") pada tahun 2019.

# %%
kategori_dm_2019 = (
    df_2019.groupby('kategori_dm')['jumlah_penderita_dm'].sum()
)

plt.figure()
plt.pie(
    kategori_dm_2019,
    labels=kategori_dm_2019.index,
    autopct='%1.1f%%',
    startangle=90
)
plt.title('Proporsi Jumlah Penderita Diabetes Mellitus Berdasarkan Kategori Tahun 2019')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13396\377181373.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_2019.groupby('kategori_dm')['jumlah_penderita_dm']

# %% [markdown]
# 24.	Buat grafik bar yang membandingkan total jumlah_penderita_dm di tiga tahun terakhir yang tersedia (misal: 2017, 2018, 2019 jika ada di dataset).

# %%
total_per_tahun = (
    df.groupby('tahun')['jumlah_penderita_dm']
      .sum()
      .reset_index()
      .sort_values('tahun')   
)

tiga_tahun_terakhir = total_per_tahun.iloc[-3:]

plt.figure()
plt.bar(
    tiga_tahun_terakhir['tahun'],
    tiga_tahun_terakhir['jumlah_penderita_dm']
)

plt.xlabel('Tahun')
plt.ylabel('Total Jumlah Penderita DM')
plt.title('Perbandingan Total Jumlah Penderita Diabetes Mellitus pada Tiga Tahun Terakhir')
plt.tight_layout()
plt.show()

# %% [markdown]
# 25.	Berdasarkan grafik-grafik yang kamu buat pada soal 20–24, tuliskan analisis tertulis yang menjawab pertanyaan berikut:

# %% [markdown]
# a. Kabupaten/kota mana yang paling tinggi jumlah penderita DM-nya? Apakah konsisten di beberapa tahun?

# %% [markdown]
# Kabupaten Karawang merupakan wilayah dengan jumlah penderita DM tertinggi. Kondisi ini tidak hanya terjadi pada satu tahun tertentu, tetapi cenderung konsisten pada beberapa tahun, khususnya pada tahun-tahun terakhir. Hal ini menunjukkan bahwa Kabupaten Karawang memiliki beban kasus DM yang relatif lebih besar dibandingkan kabupaten/kota lain di Jawa Barat.

# %% [markdown]
# b. Apakah secara umum jumlah penderita DM di Jawa Barat cenderung naik, turun, atau stabil dari tahun ke tahun?

# %% [markdown]
# Berdasarkan grafik garis dan grafik perbandingan total jumlah penderita DM pada tiga tahun terakhir (2022, 2023, dan 2024), dapat disimpulkan bahwa jumlah penderita DM di Jawa Barat secara umum menunjukkan tren meningkat dari tahun ke tahun. Meskipun peningkatannya tidak selalu signifikan setiap tahun, arah tren yang cenderung naik mengindikasikan bahwa Diabetes Mellitus masih menjadi masalah kesehatan yang perlu mendapat perhatian serius dari pemerintah dan pemangku kebijakan kesehatan.

# %% [markdown]
# c. Bagaimana sebaran kategori Rendah/Sedang/Tinggi? Lebih banyak kabupaten di kategori mana?

# %% [markdown]
# Berdasarkan pie chart yang menampilkan proporsi kategori jumlah penderita DM (Rendah, Sedang, Tinggi), terlihat bahwa sebagian besar kabupaten/kota berada pada kategori Sedang dan Tinggi, dengan kategori Tinggi mendominasi total jumlah penderita. Sementara itu, kategori Rendah hanya mencakup sebagian kecil kabupaten/kota. Hal ini menunjukkan bahwa mayoritas wilayah di Jawa Barat memiliki jumlah penderita DM yang cukup besar dan berpotensi memerlukan intervensi kesehatan yang lebih intensif.
